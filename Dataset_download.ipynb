# %% [markdown]
# <a href="https://colab.research.google.com/github/Harbiodun0122/OCR-for-Nigerian-Licence-Plate-/blob/master/Dataset_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow

# %%
from google.colab import userdata
api_key = userdata.get('ROBOFLOW_KEY')

# %%
rf = Roboflow(api_key=api_key)
project = rf.workspace("abiodun-projects").project("license-plates-o3clj-uni85")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License-Plates-1 in yolov11:: 100%|██████████| 5668/5668 [00:01<00:00, 5272.72it/s]

# %%
import shutil

# %%
shutil.copytree("/content/License-Plates-1","/content/drive/MyDrive/Licence Plate OCR/dataset")
# Out:
# '/content/drive/MyDrive/Licence Plate OCR/dataset'

# %%
import glob

# %%
def print_number(split):
    imgs = len(glob.glob(f"/content/drive/MyDrive/Licence Plate OCR/dataset/{split}/images/*.jpg"))
    lbs =  len(glob.glob(f"/content/drive/MyDrive/Licence Plate OCR/dataset/{split}/labels/*.txt"))
    return f"Number of {split} images: {imgs} \n Number of labels: {lbs}"

# %%
print_number("train")
# Out:
# 'Number of train images: 1978 \n Number of labels: 1978'

# %%
print_number("test")
# Out:
# 'Number of test images: 566 \n Number of labels: 566'

# %%
print_number("valid")
# Out:
# 'Number of valid images: 284 \n Number of labels: 284'
